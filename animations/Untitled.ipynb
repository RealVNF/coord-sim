# %%
# %matplotlib notebook
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import HTML

# %%
#%pylab inline

# %%
from animations import PlacementAnimesManager
from animations import PlacementAnime
from animations import list_tests

# %%
#pa.moments[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4bb4cd3a679b> in <module>
# ----> 1 pa.moments[0]
#
# NameError: name 'pa' is not defined

# %%
pa = PlacementAnime(".")
#pa.create_animation()
pa.create_moments()
for moment in pa.moments:
    for ln in moment:
        ln.set_visible(False)

@widgets.interact(frame=(0, 900))
def set_moment(frame):
    for moment in pa.moments[:frame]:
        for ln in moment:
            ln.set_visible(False)

    for ln in pa.moments[frame]:
        ln.set_visible(True)

    for moment in pa.moments[frame+100:]:
        for ln in moment:
            ln.set_visible(False)
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(IntSlider(value=450, description='frame', max=900), Output()), _dom_classes=('widget-int…

# %%
results_dir = "line-results-wo-prediction"

@widgets.interact(test_dir=list_tests(results_dir))
def update(test_dir):
    pa = PlacementAnime(test_dir)
    pa.create_animation()
    plt.show()
# Out:
# interactive(children=(Dropdown(description='test_dir', options=('line-results-wo-prediction/det-arrival10_det-…

# %%
#help(pa.ax)
